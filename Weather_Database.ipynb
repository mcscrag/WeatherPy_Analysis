# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000, 90.000, size = 2000)
lngs = np.random.uniform(-180.000, 180.000, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count

len(cities)
# Out:
# 758

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]      
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]  
        city_country = city_weather["sys"]["country"]
        
        # Append the city information into the city_data list
        city_data.append({
            'City':city.title(),
            'Country':city_country,
            'Lat':city_lat,
            'Lng':city_lng,
            'Max Temp':city_max_temp,
            'Humidity':city_humidity,
            'Cloudiness':city_clouds,
            'Wind Speed':city_wind,
            'Description':city_description,
        })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | cabo san lucas
# Processing Record 4 of Set 1 | bubaque
# Processing Record 5 of Set 1 | zlatoustovsk
# City not found. Skipping...
# Processing Record 6 of Set 1 | provideniya
# Processing Record 7 of Set 1 | roma
# Processing Record 8 of Set 1 | bethel
# Processing Record 9 of Set 1 | coquimbo
# Processing Record 10 of Set 1 | carballo
# Processing Record 11 of Set 1 | torbay
# Processing Record 12 of Set 1 | dyurtyuli
# Processing Record 13 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | esterhazy
# Processing Record 16 of Set 1 | balimo
# City not found. Skipping...
# Processing Record 17 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 1 | sao joao da barra
# Processing Record 19 of Set 1 | biak
# Processing Record 20 of Set 1 | whitefish
# Processing Record 21 of Set 1 | barrow
# Processing Record 22 of Set 1 | castro
# Processing Record 23 of Set 1 | ibra
# Processing Record 24 of Set 1 | srednekolymsk
# Processing Record 25 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 26 of Set 1 | nikolskoye
# Processing Record 27 of Set 1 | faanui
# Processing Record 28 of Set 1 | tiksi
# Processing Record 29 of Set 1 | vitim
# Processing Record 30 of Set 1 | manggar
# Processing Record 31 of Set 1 | hilo
# Processing Record 32 of Set 1 | kafue
# Processing Record 33 of Set 1 | tuktoyaktuk
# Processing Record 34 of Set 1 | vaini
# Processing Record 35 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | kodiak
# Processing Record 38 of Set 1 | vardo
# Processing Record 39 of Set 1 | tazovskiy
# Processing Record 40 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 1 | weiser
# Processing Record 42 of Set 1 | maiduguri
# Processing Record 43 of Set 1 | ahipara
# Processing Record 44 of Set 1 | puerto ayora
# Processing Record 45 of Set 1 | ushuaia
# Processing Record 46 of Set 1 | broome
# Processing Record 47 of Set 1 | mahebourg
# Processing Record 48 of Set 1 | port elizabeth
# Processing Record 49 of Set 1 | yar-sale
# Processing Record 50 of Set 1 | aitape
# Processing Record 1 of Set 2 | hithadhoo
# Processing Record 2 of Set 2 | dikson
# Processing Record 3 of Set 2 | morondava
# Processing Record 4 of Set 2 | coihaique
# Processing Record 5 of Set 2 | korla
# Processing Record 6 of Set 2 | bengkulu
# Processing Record 7 of Set 2 | mataura
# Processing Record 8 of Set 2 | banda aceh
# Processing Record 9 of Set 2 | qaanaaq
# Processing Record 10 of Set 2 | shambu
# Processing Record 11 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 2 | price
# Processing Record 13 of Set 2 | qunduz
# Processing Record 14 of Set 2 | jamestown
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | thinadhoo
# Processing Record 17 of Set 2 | quatre cocos
# Processing Record 18 of Set 2 | upernavik
# Processing Record 19 of Set 2 | khairpur nathan shah
# Processing Record 20 of Set 2 | naze
# Processing Record 21 of Set 2 | ilulissat
# Processing Record 22 of Set 2 | lhokseumawe
# Processing Record 23 of Set 2 | thompson
# Processing Record 24 of Set 2 | haines junction
# Processing Record 25 of Set 2 | east london
# Processing Record 26 of Set 2 | sydney mines
# Processing Record 27 of Set 2 | gat
# Processing Record 28 of Set 2 | cape town
# Processing Record 29 of Set 2 | khatanga
# Processing Record 30 of Set 2 | atuona
# Processing Record 31 of Set 2 | rawson
# Processing Record 32 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 2 | cidreira
# Processing Record 34 of Set 2 | monte patria
# Processing Record 35 of Set 2 | saint-philippe
# Processing Record 36 of Set 2 | salalah
# Processing Record 37 of Set 2 | georgetown
# Processing Record 38 of Set 2 | pangani
# Processing Record 39 of Set 2 | chuy
# Processing Record 40 of Set 2 | port lincoln
# Processing Record 41 of Set 2 | fortuna
# Processing Record 42 of Set 2 | tungor
# Processing Record 43 of Set 2 | arraial do cabo
# Processing Record 44 of Set 2 | maymyo
# Processing Record 45 of Set 2 | chara
# Processing Record 46 of Set 2 | yeppoon
# Processing Record 47 of Set 2 | karratha
# Processing Record 48 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 2 | severo-kurilsk
# Processing Record 50 of Set 2 | nishihara
# Processing Record 1 of Set 3 | sabha
# Processing Record 2 of Set 3 | skjervoy
# Processing Record 3 of Set 3 | saint george
# Processing Record 4 of Set 3 | aklavik
# Processing Record 5 of Set 3 | batagay-alyta
# Processing Record 6 of Set 3 | port alfred
# Processing Record 7 of Set 3 | bredasdorp
# Processing Record 8 of Set 3 | carnarvon
# Processing Record 9 of Set 3 | sechura
# Processing Record 10 of Set 3 | komsomolskiy
# Processing Record 11 of Set 3 | preetz
# Processing Record 12 of Set 3 | hobart
# Processing Record 13 of Set 3 | lorengau
# Processing Record 14 of Set 3 | varna
# Processing Record 15 of Set 3 | yellowknife
# Processing Record 16 of Set 3 | chokurdakh
# Processing Record 17 of Set 3 | oudtshoorn
# Processing Record 18 of Set 3 | iqaluit
# Processing Record 19 of Set 3 | falealupo
# City not found. Skipping...
# Processing Record 20 of Set 3 | necochea
# Processing Record 21 of Set 3 | poum
# Processing Record 22 of Set 3 | mandalgovi
# Processing Record 23 of Set 3 | madarounfa
# Processing Record 24 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 25 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 26 of Set 3 | chernyshevskiy
# Processing Record 27 of Set 3 | seoul
# Processing Record 28 of Set 3 | alibag
# Processing Record 29 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 3 | new norfolk
# Processing Record 31 of Set 3 | bilokurakyne
# Processing Record 32 of Set 3 | arsikere
# Processing Record 33 of Set 3 | butaritari
# Processing Record 34 of Set 3 | mount gambier
# Processing Record 35 of Set 3 | gorontalo
# Processing Record 36 of Set 3 | souillac
# Processing Record 37 of Set 3 | clyde river
# Processing Record 38 of Set 3 | beringovskiy
# Processing Record 39 of Set 3 | esperance
# Processing Record 40 of Set 3 | waingapu
# Processing Record 41 of Set 3 | dunedin
# Processing Record 42 of Set 3 | lebu
# Processing Record 43 of Set 3 | bolobo
# Processing Record 44 of Set 3 | pingliang
# Processing Record 45 of Set 3 | kavieng
# Processing Record 46 of Set 3 | itarema
# Processing Record 47 of Set 3 | mabaruma
# Processing Record 48 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 3 | florence
# Processing Record 50 of Set 3 | kapaa
# Processing Record 1 of Set 4 | puri
# Processing Record 2 of Set 4 | bara
# Processing Record 3 of Set 4 | tabarqah
# City not found. Skipping...
# Processing Record 4 of Set 4 | port-cartier
# Processing Record 5 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 4 | bom jesus
# Processing Record 7 of Set 4 | plettenberg bay
# Processing Record 8 of Set 4 | tasiilaq
# Processing Record 9 of Set 4 | labuan
# Processing Record 10 of Set 4 | tebingtinggi
# Processing Record 11 of Set 4 | kollegal
# Processing Record 12 of Set 4 | yamada
# Processing Record 13 of Set 4 | luderitz
# Processing Record 14 of Set 4 | san vicente
# Processing Record 15 of Set 4 | lagoa
# Processing Record 16 of Set 4 | asau
# Processing Record 17 of Set 4 | turinsk
# Processing Record 18 of Set 4 | zlitan
# Processing Record 19 of Set 4 | santa cruz cabralia
# Processing Record 20 of Set 4 | bluff
# Processing Record 21 of Set 4 | belle fourche
# Processing Record 22 of Set 4 | taywarah
# Processing Record 23 of Set 4 | kismayo
# Processing Record 24 of Set 4 | mount hagen
# Processing Record 25 of Set 4 | hirara
# Processing Record 26 of Set 4 | yulara
# Processing Record 27 of Set 4 | husavik
# Processing Record 28 of Set 4 | chumikan
# Processing Record 29 of Set 4 | japura
# Processing Record 30 of Set 4 | la ronge
# Processing Record 31 of Set 4 | ponta delgada
# Processing Record 32 of Set 4 | bukachacha
# Processing Record 33 of Set 4 | kamaishi
# Processing Record 34 of Set 4 | sistranda
# Processing Record 35 of Set 4 | kahului
# Processing Record 36 of Set 4 | meulaboh
# Processing Record 37 of Set 4 | changji
# Processing Record 38 of Set 4 | ocampo
# Processing Record 39 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 4 | los llanos de aridane
# Processing Record 41 of Set 4 | dingle
# Processing Record 42 of Set 4 | antropovo
# Processing Record 43 of Set 4 | evensk
# Processing Record 44 of Set 4 | camacha
# Processing Record 45 of Set 4 | bambous virieux
# Processing Record 46 of Set 4 | bilibino
# Processing Record 47 of Set 4 | touros
# Processing Record 48 of Set 4 | skogn
# Processing Record 49 of Set 4 | onega
# Processing Record 50 of Set 4 | guarapari
# Processing Record 1 of Set 5 | manokwari
# Processing Record 2 of Set 5 | port pirie
# Processing Record 3 of Set 5 | morden
# Processing Record 4 of Set 5 | pangnirtung
# Processing Record 5 of Set 5 | suntar
# Processing Record 6 of Set 5 | victoria
# Processing Record 7 of Set 5 | zhanakorgan
# Processing Record 8 of Set 5 | moratuwa
# Processing Record 9 of Set 5 | tongzi
# Processing Record 10 of Set 5 | sadowara
# City not found. Skipping...
# Processing Record 11 of Set 5 | ostrovnoy
# Processing Record 12 of Set 5 | saldanha
# Processing Record 13 of Set 5 | port hawkesbury
# Processing Record 14 of Set 5 | barabash
# Processing Record 15 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 5 | katsuura
# Processing Record 17 of Set 5 | north canton
# Processing Record 18 of Set 5 | yumen
# Processing Record 19 of Set 5 | ponta do sol
# Processing Record 20 of Set 5 | havelock
# Processing Record 21 of Set 5 | tooele
# Processing Record 22 of Set 5 | nuuk
# Processing Record 23 of Set 5 | honningsvag
# Processing Record 24 of Set 5 | dzhebariki-khaya
# Processing Record 25 of Set 5 | norman wells
# Processing Record 26 of Set 5 | cayenne
# Processing Record 27 of Set 5 | sao filipe
# Processing Record 28 of Set 5 | baijiantan
# Processing Record 29 of Set 5 | atkinson
# Processing Record 30 of Set 5 | mingshui
# Processing Record 31 of Set 5 | zhongxing
# Processing Record 32 of Set 5 | tvardica
# City not found. Skipping...
# Processing Record 33 of Set 5 | baghdad
# Processing Record 34 of Set 5 | linguere
# Processing Record 35 of Set 5 | burns lake
# Processing Record 36 of Set 5 | chagoda
# Processing Record 37 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 5 | lavrentiya
# Processing Record 39 of Set 5 | kaitangata
# Processing Record 40 of Set 5 | pevek
# Processing Record 41 of Set 5 | tsentralnyy
# City not found. Skipping...
# Processing Record 42 of Set 5 | sarangani
# Processing Record 43 of Set 5 | cockburn town
# Processing Record 44 of Set 5 | walvis bay
# Processing Record 45 of Set 5 | krasnovishersk
# Processing Record 46 of Set 5 | sitka
# Processing Record 47 of Set 5 | hammerfest
# Processing Record 48 of Set 5 | narsaq
# Processing Record 49 of Set 5 | port macquarie
# Processing Record 50 of Set 5 | luau
# Processing Record 1 of Set 6 | marsa matruh
# Processing Record 2 of Set 6 | praia da vitoria
# Processing Record 3 of Set 6 | chicama
# Processing Record 4 of Set 6 | geraldton
# Processing Record 5 of Set 6 | tual
# Processing Record 6 of Set 6 | rio gallegos
# Processing Record 7 of Set 6 | tadine
# Processing Record 8 of Set 6 | ustye
# Processing Record 9 of Set 6 | russell
# Processing Record 10 of Set 6 | qaqortoq
# Processing Record 11 of Set 6 | longyearbyen
# Processing Record 12 of Set 6 | saint-joseph
# Processing Record 13 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 6 | katobu
# Processing Record 15 of Set 6 | yuzhno-kurilsk
# Processing Record 16 of Set 6 | folkestone
# Processing Record 17 of Set 6 | toamasina
# Processing Record 18 of Set 6 | auki
# Processing Record 19 of Set 6 | brazzaville
# Processing Record 20 of Set 6 | vestmannaeyjar
# Processing Record 21 of Set 6 | balkhash
# Processing Record 22 of Set 6 | atasu
# Processing Record 23 of Set 6 | baykit
# Processing Record 24 of Set 6 | sao paulo de olivenca
# Processing Record 25 of Set 6 | kuruman
# Processing Record 26 of Set 6 | sangerhausen
# Processing Record 27 of Set 6 | nusaybin
# Processing Record 28 of Set 6 | snyder
# Processing Record 29 of Set 6 | tilichiki
# Processing Record 30 of Set 6 | pisco
# Processing Record 31 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 32 of Set 6 | san clemente
# Processing Record 33 of Set 6 | jardim
# Processing Record 34 of Set 6 | obidos
# Processing Record 35 of Set 6 | yunyang
# Processing Record 36 of Set 6 | gizo
# Processing Record 37 of Set 6 | kinsale
# Processing Record 38 of Set 6 | north battleford
# Processing Record 39 of Set 6 | anadyr
# Processing Record 40 of Set 6 | beloha
# Processing Record 41 of Set 6 | prabumulih
# Processing Record 42 of Set 6 | saint-pierre
# Processing Record 43 of Set 6 | hami
# Processing Record 44 of Set 6 | isangel
# Processing Record 45 of Set 6 | san quintin
# Processing Record 46 of Set 6 | fukue
# Processing Record 47 of Set 6 | flinders
# Processing Record 48 of Set 6 | vestmanna
# Processing Record 49 of Set 6 | hotaka
# Processing Record 50 of Set 6 | avarua
# Processing Record 1 of Set 7 | ganzhou
# Processing Record 2 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 7 | bathsheba
# Processing Record 4 of Set 7 | lompoc
# Processing Record 5 of Set 7 | tessalit
# Processing Record 6 of Set 7 | cherskiy
# Processing Record 7 of Set 7 | araouane
# Processing Record 8 of Set 7 | grand gaube
# Processing Record 9 of Set 7 | kovvur
# Processing Record 10 of Set 7 | klaksvik
# Processing Record 11 of Set 7 | palmer
# Processing Record 12 of Set 7 | amuntai
# Processing Record 13 of Set 7 | sulangan
# Processing Record 14 of Set 7 | kargasok
# Processing Record 15 of Set 7 | santa marta
# Processing Record 16 of Set 7 | saskylakh
# Processing Record 17 of Set 7 | carutapera
# Processing Record 18 of Set 7 | strasice
# Processing Record 19 of Set 7 | farafangana
# Processing Record 20 of Set 7 | chapada dos guimaraes
# Processing Record 21 of Set 7 | nouadhibou
# Processing Record 22 of Set 7 | ucluelet
# Processing Record 23 of Set 7 | severo-yeniseyskiy
# Processing Record 24 of Set 7 | mareeba
# Processing Record 25 of Set 7 | saint-augustin
# Processing Record 26 of Set 7 | lata
# Processing Record 27 of Set 7 | ondorhaan
# City not found. Skipping...
# Processing Record 28 of Set 7 | goure
# Processing Record 29 of Set 7 | narrabri
# Processing Record 30 of Set 7 | hambantota
# Processing Record 31 of Set 7 | proletarsk
# Processing Record 32 of Set 7 | simao
# Processing Record 33 of Set 7 | rumoi
# Processing Record 34 of Set 7 | pospelikha
# Processing Record 35 of Set 7 | tura
# Processing Record 36 of Set 7 | khani
# Processing Record 37 of Set 7 | blagoveshchensk
# Processing Record 38 of Set 7 | autun
# Processing Record 39 of Set 7 | grindavik
# Processing Record 40 of Set 7 | mar del plata
# Processing Record 41 of Set 7 | barahona
# Processing Record 42 of Set 7 | shingu
# Processing Record 43 of Set 7 | brae
# Processing Record 44 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 45 of Set 7 | hilpoltstein
# Processing Record 46 of Set 7 | hofn
# Processing Record 47 of Set 7 | coahuayana
# Processing Record 48 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 49 of Set 7 | lar gerd
# City not found. Skipping...
# Processing Record 50 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 1 of Set 8 | patti
# Processing Record 2 of Set 8 | tocopilla
# Processing Record 3 of Set 8 | constitucion
# Processing Record 4 of Set 8 | taoudenni
# Processing Record 5 of Set 8 | moerai
# Processing Record 6 of Set 8 | margate
# Processing Record 7 of Set 8 | yaan
# Processing Record 8 of Set 8 | mount isa
# Processing Record 9 of Set 8 | hay river
# Processing Record 10 of Set 8 | eaton socon
# Processing Record 11 of Set 8 | mitsamiouli
# Processing Record 12 of Set 8 | shenjiamen
# Processing Record 13 of Set 8 | santiago de cao
# Processing Record 14 of Set 8 | nurobod
# Processing Record 15 of Set 8 | ati
# Processing Record 16 of Set 8 | victor harbor
# Processing Record 17 of Set 8 | vila velha
# Processing Record 18 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 8 | juneau
# Processing Record 20 of Set 8 | qasigiannguit
# Processing Record 21 of Set 8 | mwinilunga
# Processing Record 22 of Set 8 | neuquen
# Processing Record 23 of Set 8 | talcahuano
# Processing Record 24 of Set 8 | kruisfontein
# Processing Record 25 of Set 8 | san angelo
# Processing Record 26 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 8 | ribeira grande
# Processing Record 28 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 8 | atar
# Processing Record 30 of Set 8 | pangody
# Processing Record 31 of Set 8 | maniitsoq
# Processing Record 32 of Set 8 | nelson bay
# Processing Record 33 of Set 8 | kariba
# Processing Record 34 of Set 8 | andevoranto
# City not found. Skipping...
# Processing Record 35 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 36 of Set 8 | caririacu
# Processing Record 37 of Set 8 | freeport
# Processing Record 38 of Set 8 | samarai
# Processing Record 39 of Set 8 | betong
# Processing Record 40 of Set 8 | sorland
# Processing Record 41 of Set 8 | jaque
# Processing Record 42 of Set 8 | ust-tsilma
# Processing Record 43 of Set 8 | nioro
# Processing Record 44 of Set 8 | bandarbeyla
# Processing Record 45 of Set 8 | terrace
# Processing Record 46 of Set 8 | ternate
# Processing Record 47 of Set 8 | nautanwa
# Processing Record 48 of Set 8 | codrington
# Processing Record 49 of Set 8 | baheri
# Processing Record 50 of Set 8 | kinshasa
# Processing Record 1 of Set 9 | that phanom
# Processing Record 2 of Set 9 | basoko
# Processing Record 3 of Set 9 | takoradi
# Processing Record 4 of Set 9 | bahia blanca
# Processing Record 5 of Set 9 | makakilo city
# Processing Record 6 of Set 9 | crossville
# Processing Record 7 of Set 9 | suclayin
# Processing Record 8 of Set 9 | hervey bay
# Processing Record 9 of Set 9 | namibe
# Processing Record 10 of Set 9 | kalevala
# Processing Record 11 of Set 9 | villarrica
# Processing Record 12 of Set 9 | santa ines
# Processing Record 13 of Set 9 | mumbwa
# Processing Record 14 of Set 9 | moctezuma
# Processing Record 15 of Set 9 | kamiiso
# Processing Record 16 of Set 9 | gunzenhausen
# Processing Record 17 of Set 9 | egvekinot
# Processing Record 18 of Set 9 | madison
# Processing Record 19 of Set 9 | boyolangu
# Processing Record 20 of Set 9 | ginir
# Processing Record 21 of Set 9 | kalengwa
# Processing Record 22 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 23 of Set 9 | pilar
# Processing Record 24 of Set 9 | kualakapuas
# Processing Record 25 of Set 9 | ankazoabo
# Processing Record 26 of Set 9 | iberia
# Processing Record 27 of Set 9 | mtwara
# Processing Record 28 of Set 9 | olafsvik
# Processing Record 29 of Set 9 | the pas
# Processing Record 30 of Set 9 | khasan
# Processing Record 31 of Set 9 | lalsk
# Processing Record 32 of Set 9 | moree
# Processing Record 33 of Set 9 | nizhniy kuranakh
# Processing Record 34 of Set 9 | belaya gora
# Processing Record 35 of Set 9 | dudinka
# Processing Record 36 of Set 9 | buchanan
# Processing Record 37 of Set 9 | bull savanna
# Processing Record 38 of Set 9 | valparaiso
# Processing Record 39 of Set 9 | marzuq
# Processing Record 40 of Set 9 | oda
# Processing Record 41 of Set 9 | along
# Processing Record 42 of Set 9 | medea
# Processing Record 43 of Set 9 | hasaki
# Processing Record 44 of Set 9 | pitimbu
# Processing Record 45 of Set 9 | allanridge
# Processing Record 46 of Set 9 | shubarshi
# Processing Record 47 of Set 9 | pafos
# Processing Record 48 of Set 9 | bonavista
# Processing Record 49 of Set 9 | bambanglipuro
# Processing Record 50 of Set 9 | tornio
# Processing Record 1 of Set 10 | karpogory
# Processing Record 2 of Set 10 | acuna
# City not found. Skipping...
# Processing Record 3 of Set 10 | fare
# Processing Record 4 of Set 10 | consuegra
# Processing Record 5 of Set 10 | louis trichardt
# Processing Record 6 of Set 10 | dien bien
# City not found. Skipping...
# Processing Record 7 of Set 10 | penzance
# Processing Record 8 of Set 10 | bhan
# Processing Record 9 of Set 10 | kayseri
# Processing Record 10 of Set 10 | pandan
# Processing Record 11 of Set 10 | dumai
# Processing Record 12 of Set 10 | kirakira
# Processing Record 13 of Set 10 | ballina
# Processing Record 14 of Set 10 | turkistan
# Processing Record 15 of Set 10 | bulnes
# Processing Record 16 of Set 10 | fengcheng
# Processing Record 17 of Set 10 | marawi
# Processing Record 18 of Set 10 | kattivakkam
# Processing Record 19 of Set 10 | pudozh
# Processing Record 20 of Set 10 | port hedland
# Processing Record 21 of Set 10 | vega de alatorre
# Processing Record 22 of Set 10 | sol-iletsk
# Processing Record 23 of Set 10 | hamilton
# Processing Record 24 of Set 10 | poya
# Processing Record 25 of Set 10 | bukama
# Processing Record 26 of Set 10 | ghanzi
# Processing Record 27 of Set 10 | banjar
# Processing Record 28 of Set 10 | rogovatoye
# Processing Record 29 of Set 10 | leeuwarden
# Processing Record 30 of Set 10 | ola
# Processing Record 31 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 32 of Set 10 | krasnoselkup
# Processing Record 33 of Set 10 | innisfail
# Processing Record 34 of Set 10 | vao
# Processing Record 35 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 36 of Set 10 | carndonagh
# Processing Record 37 of Set 10 | airai
# Processing Record 38 of Set 10 | sobolevo
# Processing Record 39 of Set 10 | kemin
# Processing Record 40 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 41 of Set 10 | comacchio
# Processing Record 42 of Set 10 | asfi
# Processing Record 43 of Set 10 | kununurra
# Processing Record 44 of Set 10 | hirado
# Processing Record 45 of Set 10 | belmonte
# Processing Record 46 of Set 10 | saint-denis
# Processing Record 47 of Set 10 | gumdag
# Processing Record 48 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 49 of Set 10 | tolaga bay
# Processing Record 50 of Set 10 | kysyl-syr
# Processing Record 1 of Set 11 | hastings
# Processing Record 2 of Set 11 | bainbridge
# Processing Record 3 of Set 11 | murud
# Processing Record 4 of Set 11 | zilair
# Processing Record 5 of Set 11 | griffith
# Processing Record 6 of Set 11 | kieta
# Processing Record 7 of Set 11 | balabac
# Processing Record 8 of Set 11 | ust-koksa
# Processing Record 9 of Set 11 | cuamba
# Processing Record 10 of Set 11 | opuwo
# Processing Record 11 of Set 11 | dukat
# Processing Record 12 of Set 11 | alnashi
# Processing Record 13 of Set 11 | tiznit
# Processing Record 14 of Set 11 | kushiro
# Processing Record 15 of Set 11 | lithgow
# Processing Record 16 of Set 11 | narasannapeta
# Processing Record 17 of Set 11 | hohhot
# Processing Record 18 of Set 11 | ishigaki
# Processing Record 19 of Set 11 | bacolod
# Processing Record 20 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 21 of Set 11 | akdagmadeni
# Processing Record 22 of Set 11 | chisec
# Processing Record 23 of Set 11 | belyy yar
# Processing Record 24 of Set 11 | muros
# Processing Record 25 of Set 11 | bontang
# Processing Record 26 of Set 11 | lao cai
# Processing Record 27 of Set 11 | ayagoz
# Processing Record 28 of Set 11 | karlshamn
# Processing Record 29 of Set 11 | papara
# Processing Record 30 of Set 11 | ekhabi
# Processing Record 31 of Set 11 | smithers
# Processing Record 32 of Set 11 | san juan
# Processing Record 33 of Set 11 | mikkeli
# Processing Record 34 of Set 11 | kasempa
# Processing Record 35 of Set 11 | carauari
# Processing Record 36 of Set 11 | oussouye
# Processing Record 37 of Set 11 | inhambane
# Processing Record 38 of Set 11 | razdolinsk
# Processing Record 39 of Set 11 | kapit
# Processing Record 40 of Set 11 | bedele
# Processing Record 41 of Set 11 | wamba
# Processing Record 42 of Set 11 | rabo de peixe
# Processing Record 43 of Set 11 | metsovon
# City not found. Skipping...
# Processing Record 44 of Set 11 | caravelas
# Processing Record 45 of Set 11 | upata
# Processing Record 46 of Set 11 | mozarlandia
# Processing Record 47 of Set 11 | zambezi
# Processing Record 48 of Set 11 | taitung
# Processing Record 49 of Set 11 | porto santo
# Processing Record 50 of Set 11 | maraba
# Processing Record 1 of Set 12 | arlit
# Processing Record 2 of Set 12 | socastee
# Processing Record 3 of Set 12 | san cristobal
# Processing Record 4 of Set 12 | awbari
# Processing Record 5 of Set 12 | kapoeta
# Processing Record 6 of Set 12 | flin flon
# Processing Record 7 of Set 12 | sidhpura
# Processing Record 8 of Set 12 | barcelos
# Processing Record 9 of Set 12 | vana-voidu
# City not found. Skipping...
# Processing Record 10 of Set 12 | alice springs
# Processing Record 11 of Set 12 | berlevag
# Processing Record 12 of Set 12 | slave lake
# Processing Record 13 of Set 12 | nome
# Processing Record 14 of Set 12 | ambon
# Processing Record 15 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 16 of Set 12 | mayo
# Processing Record 17 of Set 12 | tiarei
# Processing Record 18 of Set 12 | pitrufquen
# Processing Record 19 of Set 12 | umm lajj
# Processing Record 20 of Set 12 | san patricio
# Processing Record 21 of Set 12 | claresholm
# Processing Record 22 of Set 12 | tagusao
# Processing Record 23 of Set 12 | chokwe
# Processing Record 24 of Set 12 | fairbanks
# Processing Record 25 of Set 12 | maragogi
# Processing Record 26 of Set 12 | samarinda
# Processing Record 27 of Set 12 | kendari
# Processing Record 28 of Set 12 | fuxin
# Processing Record 29 of Set 12 | cookshire
# City not found. Skipping...
# Processing Record 30 of Set 12 | jalalpur jattan
# Processing Record 31 of Set 12 | alyangula
# Processing Record 32 of Set 12 | mocuba
# Processing Record 33 of Set 12 | purpe
# Processing Record 34 of Set 12 | te anau
# Processing Record 35 of Set 12 | tarbagatay
# Processing Record 36 of Set 12 | christiana
# Processing Record 37 of Set 12 | depok
# Processing Record 38 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 39 of Set 12 | mbandaka
# Processing Record 40 of Set 12 | shimoda
# Processing Record 41 of Set 12 | kalmar
# Processing Record 42 of Set 12 | launceston
# Processing Record 43 of Set 12 | palmares do sul
# Processing Record 44 of Set 12 | koutiala
# Processing Record 45 of Set 12 | saint-leu
# Processing Record 46 of Set 12 | gambo
# Processing Record 47 of Set 12 | vila franca do campo
# Processing Record 48 of Set 12 | takhli
# Processing Record 49 of Set 12 | depew
# Processing Record 50 of Set 12 | ambilobe
# Processing Record 1 of Set 13 | chapais
# Processing Record 2 of Set 13 | hualmay
# Processing Record 3 of Set 13 | merauke
# Processing Record 4 of Set 13 | champerico
# Processing Record 5 of Set 13 | primorsko-akhtarsk
# Processing Record 6 of Set 13 | correntina
# Processing Record 7 of Set 13 | la romana
# Processing Record 8 of Set 13 | daru
# Processing Record 9 of Set 13 | montclair
# Processing Record 10 of Set 13 | yinchuan
# Processing Record 11 of Set 13 | verkhoyansk
# Processing Record 12 of Set 13 | zhanaozen
# Processing Record 13 of Set 13 | havre-saint-pierre
# Processing Record 14 of Set 13 | pasinler
# Processing Record 15 of Set 13 | achisay
# City not found. Skipping...
# Processing Record 16 of Set 13 | ulladulla
# Processing Record 17 of Set 13 | karlstad
# Processing Record 18 of Set 13 | sunndalsora
# Processing Record 19 of Set 13 | amapa
# Processing Record 20 of Set 13 | inverell
# Processing Record 21 of Set 13 | cap malheureux
# Processing Record 22 of Set 13 | jaru
# Processing Record 23 of Set 13 | sinnamary
# Processing Record 24 of Set 13 | cervo
# Processing Record 25 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 13 | aksu
# Processing Record 27 of Set 13 | a
# City not found. Skipping...
# Processing Record 28 of Set 13 | kotelnikovo
# Processing Record 29 of Set 13 | vidim
# Processing Record 30 of Set 13 | tank
# Processing Record 31 of Set 13 | panguna
# Processing Record 32 of Set 13 | talnakh
# Processing Record 33 of Set 13 | blackfalds
# Processing Record 34 of Set 13 | sinop
# Processing Record 35 of Set 13 | lokosovo
# Processing Record 36 of Set 13 | lodingen
# Processing Record 37 of Set 13 | kiruna
# Processing Record 38 of Set 13 | verkhoshizhemye
# Processing Record 39 of Set 13 | perth
# Processing Record 40 of Set 13 | todos santos
# Processing Record 41 of Set 13 | rocha
# Processing Record 42 of Set 13 | sinjai
# Processing Record 43 of Set 13 | puerto rondon
# Processing Record 44 of Set 13 | del rio
# Processing Record 45 of Set 13 | thio
# Processing Record 46 of Set 13 | atherton
# Processing Record 47 of Set 13 | zolotinka
# City not found. Skipping...
# Processing Record 48 of Set 13 | ust-omchug
# Processing Record 49 of Set 13 | clarence town
# Processing Record 50 of Set 13 | trincomalee
# Processing Record 1 of Set 14 | tigzirt
# Processing Record 2 of Set 14 | inirida
# Processing Record 3 of Set 14 | wau
# Processing Record 4 of Set 14 | sahuaripa
# Processing Record 5 of Set 14 | richards bay
# Processing Record 6 of Set 14 | borovskoy
# Processing Record 7 of Set 14 | praya
# Processing Record 8 of Set 14 | college
# Processing Record 9 of Set 14 | artigas
# Processing Record 10 of Set 14 | vostok
# Processing Record 11 of Set 14 | ovalle
# Processing Record 12 of Set 14 | kijaba
# City not found. Skipping...
# Processing Record 13 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 14 | san jose
# Processing Record 15 of Set 14 | huarmey
# Processing Record 16 of Set 14 | payo
# Processing Record 17 of Set 14 | padre bernardo
# Processing Record 18 of Set 14 | raudeberg
# Processing Record 19 of Set 14 | brownwood
# Processing Record 20 of Set 14 | badulla
# Processing Record 21 of Set 14 | tacuarembo
# Processing Record 22 of Set 14 | verkhnyaya inta
# Processing Record 23 of Set 14 | adrar
# Processing Record 24 of Set 14 | ushtobe
# Processing Record 25 of Set 14 | graham
# Processing Record 26 of Set 14 | darhan
# Processing Record 27 of Set 14 | bolshaya rechka
# Processing Record 28 of Set 14 | gamba
# Processing Record 29 of Set 14 | bilma
# Processing Record 30 of Set 14 | chimore
# Processing Record 31 of Set 14 | faya
# Processing Record 32 of Set 14 | cururupu
# Processing Record 33 of Set 14 | tecoanapa
# Processing Record 34 of Set 14 | desaguadero
# Processing Record 35 of Set 14 | banon
# Processing Record 36 of Set 14 | tokoroa
# Processing Record 37 of Set 14 | pouebo
# Processing Record 38 of Set 14 | beidao
# Processing Record 39 of Set 14 | eyl
# Processing Record 40 of Set 14 | bauchi
# Processing Record 41 of Set 14 | topolobampo
# Processing Record 42 of Set 14 | guymon
# Processing Record 43 of Set 14 | grand-lahou
# Processing Record 44 of Set 14 | alofi
# Processing Record 45 of Set 14 | ilo
# Processing Record 46 of Set 14 | diamantino
# Processing Record 47 of Set 14 | lalmohan
# Processing Record 48 of Set 14 | aketi
# Processing Record 49 of Set 14 | nokaneng
# Processing Record 50 of Set 14 | kefamenanu
# Processing Record 1 of Set 15 | aquidauana
# Processing Record 2 of Set 15 | simpang
# Processing Record 3 of Set 15 | dhidhdhoo
# Processing Record 4 of Set 15 | lieto
# Processing Record 5 of Set 15 | one hundred mile house
# City not found. Skipping...
# Processing Record 6 of Set 15 | cristalina
# Processing Record 7 of Set 15 | karatsu
# Processing Record 8 of Set 15 | sindor
# Processing Record 9 of Set 15 | majholi
# Processing Record 10 of Set 15 | roscommon
# Processing Record 11 of Set 15 | palauig
# Processing Record 12 of Set 15 | tateyama
# Processing Record 13 of Set 15 | leningradskiy
# Processing Record 14 of Set 15 | guerrero negro
# Processing Record 15 of Set 15 | ketchikan
# Processing Record 16 of Set 15 | tomaszow lubelski
# Processing Record 17 of Set 15 | sena madureira
# Processing Record 18 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 19 of Set 15 | doha
# Processing Record 20 of Set 15 | nehe
# Processing Record 21 of Set 15 | rocky mountain house
# Processing Record 22 of Set 15 | elmira
# Processing Record 23 of Set 15 | maarianhamina
# Processing Record 24 of Set 15 | kemalpasa
# Processing Record 25 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 26 of Set 15 | nanortalik
# Processing Record 27 of Set 15 | terrasini
# Processing Record 28 of Set 15 | mantua
# Processing Record 29 of Set 15 | hopkinsville
# Processing Record 30 of Set 15 | ijaki
# City not found. Skipping...
# Processing Record 31 of Set 15 | orlik
# Processing Record 32 of Set 15 | leshukonskoye
# Processing Record 33 of Set 15 | marsh harbour
# Processing Record 34 of Set 15 | tailai
# Processing Record 35 of Set 15 | xuddur
# Processing Record 36 of Set 15 | hauterive
# Processing Record 37 of Set 15 | bucerias
# Processing Record 38 of Set 15 | copala
# Processing Record 39 of Set 15 | walla walla
# Processing Record 40 of Set 15 | ayan
# Processing Record 41 of Set 15 | inuvik
# Processing Record 42 of Set 15 | yantal
# Processing Record 43 of Set 15 | jalu
# Processing Record 44 of Set 15 | wembley
# Processing Record 45 of Set 15 | naryan-mar
# Processing Record 46 of Set 15 | finschhafen
# Processing Record 47 of Set 15 | amvrosiyivka
# Processing Record 48 of Set 15 | arman
# Processing Record 49 of Set 15 | avera
# Processing Record 50 of Set 15 | susanville
# Processing Record 1 of Set 16 | fort nelson
# Processing Record 2 of Set 16 | anchorage
# Processing Record 3 of Set 16 | rio grande
# Processing Record 4 of Set 16 | paamiut
# Processing Record 5 of Set 16 | datia
# Processing Record 6 of Set 16 | baturaja
# Processing Record 7 of Set 16 | hvammstangi
# City not found. Skipping...
# Processing Record 8 of Set 16 | kachiry
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 698

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Busselton      AU -33.6500  115.3333     60.73        69           0
# 1          Albany      US  42.6001  -73.9662     29.68        62          84
# 2  Cabo San Lucas      MX  22.8909 -109.9124     71.51        64          75
# 3         Bubaque      GW  11.2833  -15.8333     79.75        43           7
# 4     Provideniya      RU  64.3833 -173.3000     19.76        98         100
# 5            Roma      US  43.2128  -75.4557     23.72        74         100
# 6          Bethel      US  41.3712  -73.4140     38.19        66          75
# 7        Coquimbo      CL -29.9533  -71.3436     71.33        64          20
# 8        Carballo      ES  43.2130   -8.6910     57.06        75          25
# 9          Torbay      CA  47.6666  -52.7314     33.89        92         100
#
#    Wind Speed       Description
# 0       18.48         clear sky
# 1        3.00     broken clouds
# 2        3.44     broken clouds
# 3        8.05         clear sky
# 4        1.14   overcast clouds
# 5        9.22   overcast clouds
# 6        9.22     broken clouds
# 7        9.22        few clouds
# 8        6.35  scattered clouds
# 9        9.22   overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed', 'Description']

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0         Busselton      AU -33.6500  115.3333     60.73        69
# 1            Albany      US  42.6001  -73.9662     29.68        62
# 2    Cabo San Lucas      MX  22.8909 -109.9124     71.51        64
# 3           Bubaque      GW  11.2833  -15.8333     79.75        43
# 4       Provideniya      RU  64.3833 -173.3000     19.76        98
# ..              ...     ...      ...       ...       ...       ...
# 693      Rio Grande      BR -32.0350  -52.0986     89.71        59
# 694         Paamiut      GL  61.9940  -49.6678     12.61        69
# 695           Datia      IN  25.6667   78.4667     58.35        68
# 696        Baturaja      ID  -4.1333  104.1667     73.47        97
# 697         Kachiry      KZ  53.0675   76.1036     -8.03        95
#
#      Cloudiness  Wind Speed      Description
# 0             0       18.48        clear sky
# 1            84        3.00    broken clouds
# 2            75        3.44    broken clouds
# 3             7        8.05        clear sky
# 4           100        1.14  overcast clouds
# ..          ...         ...              ...
# 693           5       11.14        clear sky
# 694         100        9.78  overcast clouds
# 695           0        6.93        clear sky
# 696          99        4.00  overcast clouds
# 697          82        1.32    broken clouds
#
# [698 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_filename = 'WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_filename, index_label='City_ID')
